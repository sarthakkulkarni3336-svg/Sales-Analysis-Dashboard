# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\my projects\python  p-1\Retail_sales_Data\sales data.csv\Sales_Data.csv")

# %%
print(df.head())
# Out:
#    Order_ID        Date Region     Category  Sales  Profit
# 0      1001  01-01-2025  North  Electronics  25000    5000
# 1      1002  02-01-2025  South    Furniture  15000    3000
# 2      1003  03-01-2025   East     Clothing   8000    1200
# 3      1004  04-01-2025   West  Electronics  30000    7000
# 4      1005  05-01-2025  North    Furniture  18000    2500

# %%
print(df.shape)
# Out:
# (10, 6)

# %%
print(df.columns)
# Out:
# Index(['Order_ID', 'Date', 'Region', 'Category', 'Sales', 'Profit'], dtype='str')

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of    Order_ID        Date Region     Category  Sales  Profit
# 0      1001  01-01-2025  North  Electronics  25000    5000
# 1      1002  02-01-2025  South    Furniture  15000    3000
# 2      1003  03-01-2025   East     Clothing   8000    1200
# 3      1004  04-01-2025   West  Electronics  30000    7000
# 4      1005  05-01-2025  North    Furniture  18000    2500
# 5      1006  06-01-2025  South     Clothing   9000    1500
# 6      1007  07-01-2025   East  Electronics  35000    8000
# 7      1008  08-01-2025   West    Furniture  22000    4000
# 8      1009  09-01-2025  North     Clothing  12000    2000
# 9      1010  10-01-2025  South  Electronics  28000    6000>

# %%
print(df.describe())
# Out:
#          Order_ID         Sales       Profit
# count    10.00000     10.000000    10.000000
# mean   1005.50000  20200.000000  4020.000000
# std       3.02765   9283.198682  2388.304838
# min    1001.00000   8000.000000  1200.000000
# 25%    1003.25000  12750.000000  2125.000000
# 50%    1005.50000  20000.000000  3500.000000
# 75%    1007.75000  27250.000000  5750.000000
# max    1010.00000  35000.000000  8000.000000

# %%
print(df.isnull().sum())
# Out:
# Order_ID    0
# Date        0
# Region      0
# Category    0
# Sales       0
# Profit      0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
total_sales = df ["Sales"].sum()
print("Total Sales:",total_sales)
# Out:
# Total Sales: 202000

# %%
total_profit = df ["Profit"].sum()
print("Total Profit:",total_profit)
# Out:
# Total Profit: 40200

# %%
print("Total Orders:",df["Order_ID"].count())

print("Average Sales:",
      df["Sales"].mean())

print("Maximum Sales:",
      df["Sales"].max())

print("Minimum Sales:",
      df["Sales"].min())
# Out:
# Total Orders: 10
# Average Sales: 20200.0
# Maximum Sales: 35000
# Minimum Sales: 8000

# %%
region_sales = df.groupby("Region")["Sales"].sum()
print(region_sales)
# Out:
# Region
# East     43000
# North    55000
# South    52000
# West     52000
# Name: Sales, dtype: int64

# %%
best_region = region_sales.idxmax()

print("Best Region:",
      best_region)
# Out:
# Best Region: North

# %%
category_sales = df.groupby("Category")["Sales"].sum()

print(category_sales)
# Out:
# Category
# Clothing        29000
# Electronics    118000
# Furniture       55000
# Name: Sales, dtype: int64

# %%
best_category = category_sales.idxmax()

print("Best Category:",
      best_category)
# Out:
# Best Category: Electronics

# %%
region_sales.plot(kind="bar")

plt.title("Sales by Region")

plt.xlabel("Region")

plt.ylabel("Sales")

plt.show()

# %%
plt.pie(
    category_sales,
    labels=category_sales.index,
    autopct='%1.1f%%'
)

plt.title("Category Sales")

plt.show()

# %%
profit_region = df.groupby("Region")["Profit"].sum()

print(profit_region)
# Out:
# Region
# East      9200
# North     9500
# South    10500
# West     11000
# Name: Profit, dtype: int64

# %%
profit_region.plot(kind="bar")

plt.title("Profit by Region")

plt.show()

# %%
corr = df[['Sales','Profit']].corr()

print(corr)
# Out:
#           Sales   Profit
# Sales   1.00000  0.98256
# Profit  0.98256  1.00000

# %%
sns.heatmap(
    corr,
    annot=True
)

plt.show()
